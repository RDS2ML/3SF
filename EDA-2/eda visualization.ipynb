# %% [markdown]
# ## **eda visualization**

# %%
import pandas as pd 
import seaborn as sns
import statistics as stacs

# %%
model = pd.read_csv('data/model.csv', sep=',', index_col=False)
model.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      662 non-null    str
#  1   Year       662 non-null    int64
#  2   Waist      662 non-null    float64
#  3   Hips       662 non-null    float64
#  4   Height     662 non-null    float64
#  5   Weight     662 non-null    float64
#  6   BMI        662 non-null    float64
#  7   Waist/Hip  662 non-null    float64
# dtypes: float64(6), int64(1), str(1)
# memory usage: 41.5 KB

# %% [markdown]
# #### Матрица корреляций/Тепловая матрица корреляций

# %%
model.corr(numeric_only=True)
sns.heatmap(model.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### scatterplot

# %%
sns.scatterplot(data=model, x="Waist/Hip", y="Waist");

# %%
sns.scatterplot(data=model, x="Weight", y="Year");

# %% [markdown]
# ### **pairplot**

# %%
sns.pairplot(model);

# %% [markdown]
# ### a bit of practice

# %%
# correlation ratio
display(round(model[['Weight', 'Height']].corr(), 2))
# mean value for weight and height with using statistics lib
print('Weight', round(stacs.mean(model['Weight']), 2))
print('Height', round(stacs.mean(model['Height']), 2))
# Out:
#         Weight  Height
# Weight    1.00    0.71
# Height    0.71    1.00
# Weight 114.94
# Height 66.06
